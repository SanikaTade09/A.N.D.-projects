# %% [markdown]
# <a href="https://colab.research.google.com/github/SanikaTade09/A.N.D.-projects/blob/main/Minor_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
import lightgbm as lgb

from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('/content/used_car_dataset.csv')

# %%
data
# Out:
#                                                car_name car_price_in_rupees  \
# 0     Hyundai Grand i10 Magna 1.2 Kappa VTVT [2017-2...         ₹ 4.45 Lakh
# 1                            Maruti Suzuki Alto 800 Lxi         ₹ 2.93 Lakh
# 2                               Tata Safari XZ Plus New        ₹ 22.49 Lakh
# 3                               Maruti Suzuki Ciaz ZXI+         ₹ 6.95 Lakh
# 4        Jeep Compass Sport Plus 1.4 Petrol [2019-2020]           ₹ 12 Lakh
# ...                                                 ...                 ...
# 2100                         Ford Figo Titanium1.5 TDCi          ₹ 3.6 Lakh
# 2101                    MINI Cooper Countryman Cooper D           ₹ 22 Lakh
# 2102                          Hyundai Verna 1.6 VTVT SX         ₹ 8.38 Lakh
# 2103                         Maruti Suzuki Ciaz VXi+ AT         ₹ 6.75 Lakh
# 2104                          Hyundai Verna 1.6 VTVT SX         ₹ 8.76 Lakh
#
#      kms_driven fuel_type       city  year_of_manufacture
# 0     22,402 km    Petrol     Mumbai                 2016
# 1     10,344 km    Petrol    Kolkata                 2019
# 2     12,999 km    Diesel  Bangalore                 2021
# 3     45,000 km    Petrol      Thane                 2016
# 4     11,193 km    Petrol    Kolkata                 2019
# ...         ...       ...        ...                  ...
# 2100  42,158 km    Diesel    Kolkata                 2015
# 2101  68,862 km    Diesel  Hyderabad                 2013
# 2102  37,622 km    Petrol    Chennai                 2018
# 2103  64,726 km    Petrol     Mumbai                 2017
# 2104  29,150 km    Petrol       Pune                 2017
#
# [2105 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105 entries, 0 to 2104
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             2105 non-null   object
#  1   car_price_in_rupees  2105 non-null   object
#  2   kms_driven           2105 non-null   object
#  3   fuel_type            2105 non-null   object
#  4   city                 2105 non-null   object
#  5   year_of_manufacture  2105 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 98.8+ KB

# %%
data.isna().sum()
# Out:
# car_name               0
# car_price_in_rupees    0
# kms_driven             0
# fuel_type              0
# city                   0
# year_of_manufacture    0
# dtype: int64

# %%
null_columns = data.columns[data.isna().mean() > 0.25]

data = data.drop(null_columns, axis=1)

# %%
data
# Out:
#                                                car_name car_price_in_rupees  \
# 0     Hyundai Grand i10 Magna 1.2 Kappa VTVT [2017-2...         ₹ 4.45 Lakh
# 1                            Maruti Suzuki Alto 800 Lxi         ₹ 2.93 Lakh
# 2                               Tata Safari XZ Plus New        ₹ 22.49 Lakh
# 3                               Maruti Suzuki Ciaz ZXI+         ₹ 6.95 Lakh
# 4        Jeep Compass Sport Plus 1.4 Petrol [2019-2020]           ₹ 12 Lakh
# ...                                                 ...                 ...
# 2100                         Ford Figo Titanium1.5 TDCi          ₹ 3.6 Lakh
# 2101                    MINI Cooper Countryman Cooper D           ₹ 22 Lakh
# 2102                          Hyundai Verna 1.6 VTVT SX         ₹ 8.38 Lakh
# 2103                         Maruti Suzuki Ciaz VXi+ AT         ₹ 6.75 Lakh
# 2104                          Hyundai Verna 1.6 VTVT SX         ₹ 8.76 Lakh
#
#      kms_driven fuel_type       city  year_of_manufacture
# 0     22,402 km    Petrol     Mumbai                 2016
# 1     10,344 km    Petrol    Kolkata                 2019
# 2     12,999 km    Diesel  Bangalore                 2021
# 3     45,000 km    Petrol      Thane                 2016
# 4     11,193 km    Petrol    Kolkata                 2019
# ...         ...       ...        ...                  ...
# 2100  42,158 km    Diesel    Kolkata                 2015
# 2101  68,862 km    Diesel  Hyderabad                 2013
# 2102  37,622 km    Petrol    Chennai                 2018
# 2103  64,726 km    Petrol     Mumbai                 2017
# 2104  29,150 km    Petrol       Pune                 2017
#
# [2105 rows x 6 columns]

# %%
data
# Out:
#                                                car_name car_price_in_rupees  \
# 0     Hyundai Grand i10 Magna 1.2 Kappa VTVT [2017-2...         ₹ 4.45 Lakh
# 1                            Maruti Suzuki Alto 800 Lxi         ₹ 2.93 Lakh
# 2                               Tata Safari XZ Plus New        ₹ 22.49 Lakh
# 3                               Maruti Suzuki Ciaz ZXI+         ₹ 6.95 Lakh
# 4        Jeep Compass Sport Plus 1.4 Petrol [2019-2020]           ₹ 12 Lakh
# ...                                                 ...                 ...
# 2100                         Ford Figo Titanium1.5 TDCi          ₹ 3.6 Lakh
# 2101                    MINI Cooper Countryman Cooper D           ₹ 22 Lakh
# 2102                          Hyundai Verna 1.6 VTVT SX         ₹ 8.38 Lakh
# 2103                         Maruti Suzuki Ciaz VXi+ AT         ₹ 6.75 Lakh
# 2104                          Hyundai Verna 1.6 VTVT SX         ₹ 8.76 Lakh
#
#      kms_driven fuel_type       city  year_of_manufacture
# 0     22,402 km    Petrol     Mumbai                 2016
# 1     10,344 km    Petrol    Kolkata                 2019
# 2     12,999 km    Diesel  Bangalore                 2021
# 3     45,000 km    Petrol      Thane                 2016
# 4     11,193 km    Petrol    Kolkata                 2019
# ...         ...       ...        ...                  ...
# 2100  42,158 km    Diesel    Kolkata                 2015
# 2101  68,862 km    Diesel  Hyderabad                 2013
# 2102  37,622 km    Petrol    Chennai                 2018
# 2103  64,726 km    Petrol     Mumbai                 2017
# 2104  29,150 km    Petrol       Pune                 2017
#
# [2105 rows x 6 columns]

# %%
{column: len(data[column].unique()) for column in data.columns if data.dtypes[column] == 'object'}
# Out:
# {'car_name': 946,
#  'car_price_in_rupees': 811,
#  'kms_driven': 1628,
#  'fuel_type': 8,
#  'city': 16}

# %%
data = data.drop('kms_driven', axis=1)

# %%
def onehot_encode(df, columns, prefixes):
    df = df.copy()
    for column, prefix in zip(columns, prefixes):
        dummies = pd.get_dummies(df[column], prefix=prefix)
        df = pd.concat([df, dummies], axis=1)
        df = df.drop(column, axis=1)
    return df

# %%
data = onehot_encode(
    data,
    ['car_name', 'car_price_in_rupees', 'fuel_type', 'city'],
    ['cname', 'price', 'fname', 'state']
)

# %%
data
# Out:
#       year_of_manufacture  cname_Audi A3 35 TDI Premium + Sunroof  \
# 0                    2016                                   False
# 1                    2019                                   False
# 2                    2021                                   False
# 3                    2016                                   False
# 4                    2019                                   False
# ...                   ...                                     ...
# 2100                 2015                                   False
# 2101                 2013                                   False
# 2102                 2018                                   False
# 2103                 2017                                   False
# 2104                 2017                                   False
#
#       cname_Audi A3 35 TDI Premium Plus  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 2100                              False
# 2101                              False
# 2102                              False
# 2103                              False
# 2104                              False
#
#       cname_Audi A3 35 TDI Premium Plus + Sunroof  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 2100                                        False
# 2101                                        False
# 2102                                        False
# 2103                                        False
# 2104                                        False
#
#       cname_Audi A3 35 TDI Technology + Sunroof  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 2100                                      False
# 2101                                      False
# 2102                                      False
# 2103                                      False
# 2104                                      False
#
#       cname_Audi A3 35 TFSI Premium Plus  cname_Audi A3 40 TFSI Premium  \
# 0                                  False                          False
# 1                                  False                          False
# 2                                  False                          False
# 3                                  False                          False
# 4                                  False                          False
# ...                                  ...                            ...
# 2100                               False                          False
# 2101                               False                          False
# 2102                               False                          False
# 2103                               False                          False
# 2104                               False                          False
#
#       cname_Audi A3 40 TFSI Premium Plus + sunroof  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 2100                                         False
# 2101                                         False
# 2102                                         False
# 2103                                         False
# 2104                                         False
#
#       cname_Audi A4 2.0 TDI (143 bhp)  cname_Audi A4 2.0 TDI (143bhp)  ...  \
# 0                               False                           False  ...
# 1                               False                           False  ...
# 2                               False                           False  ...
# 3                               False                           False  ...
# 4                               False                           False  ...
# ...                               ...                             ...  ...
# 2100                            False                           False  ...
# 2101                            False                           False  ...
# 2102                            False                           False  ...
# 2103                            False                           False  ...
# 2104                            False                           False  ...
#
#       state_Gurgaon  state_Hyderabad  state_Kolkata  state_Mumbai  \
# 0             False            False          False          True
# 1             False            False           True         False
# 2             False            False          False         False
# 3             False            False          False         False
# 4             False            False           True         False
# ...             ...              ...            ...           ...
# 2100          False            False           True         False
# 2101          False             True          False         False
# 2102          False            False          False         False
# 2103          False            False          False          True
# 2104          False            False          False         False
#
#       state_Noida  state_Pallikarnai  state_Poonamallee  state_Pune  \
# 0           False              False              False       False
# 1           False              False              False       False
# 2           False              False              False       False
# 3           False              False              False       False
# 4           False              False              False       False
# ...           ...                ...                ...         ...
# 2100        False              False              False       False
# 2101        False              False              False       False
# 2102        False              False              False       False
# 2103        False              False              False       False
# 2104        False              False              False        True
#
#       state_Thane  state_Thiruvallur
# 0           False              False
# 1           False              False
# 2           False              False
# 3            True              False
# 4           False              False
# ...           ...                ...
# 2100        False              False
# 2101        False              False
# 2102        False              False
# 2103        False              False
# 2104        False              False
#
# [2105 rows x 1782 columns]

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
y = data.loc[:, 'year_of_manufacture']
X = data.drop('year_of_manufacture', axis=1)

# %%
data
# Out:
#       year_of_manufacture  cname_Audi A3 35 TDI Premium + Sunroof  \
# 0                    2016                                   False
# 1                    2019                                   False
# 2                    2021                                   False
# 3                    2016                                   False
# 4                    2019                                   False
# ...                   ...                                     ...
# 2100                 2015                                   False
# 2101                 2013                                   False
# 2102                 2018                                   False
# 2103                 2017                                   False
# 2104                 2017                                   False
#
#       cname_Audi A3 35 TDI Premium Plus  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 2100                              False
# 2101                              False
# 2102                              False
# 2103                              False
# 2104                              False
#
#       cname_Audi A3 35 TDI Premium Plus + Sunroof  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 2100                                        False
# 2101                                        False
# 2102                                        False
# 2103                                        False
# 2104                                        False
#
#       cname_Audi A3 35 TDI Technology + Sunroof  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 2100                                      False
# 2101                                      False
# 2102                                      False
# 2103                                      False
# 2104                                      False
#
#       cname_Audi A3 35 TFSI Premium Plus  cname_Audi A3 40 TFSI Premium  \
# 0                                  False                          False
# 1                                  False                          False
# 2                                  False                          False
# 3                                  False                          False
# 4                                  False                          False
# ...                                  ...                            ...
# 2100                               False                          False
# 2101                               False                          False
# 2102                               False                          False
# 2103                               False                          False
# 2104                               False                          False
#
#       cname_Audi A3 40 TFSI Premium Plus + sunroof  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 2100                                         False
# 2101                                         False
# 2102                                         False
# 2103                                         False
# 2104                                         False
#
#       cname_Audi A4 2.0 TDI (143 bhp)  cname_Audi A4 2.0 TDI (143bhp)  ...  \
# 0                               False                           False  ...
# 1                               False                           False  ...
# 2                               False                           False  ...
# 3                               False                           False  ...
# 4                               False                           False  ...
# ...                               ...                             ...  ...
# 2100                            False                           False  ...
# 2101                            False                           False  ...
# 2102                            False                           False  ...
# 2103                            False                           False  ...
# 2104                            False                           False  ...
#
#       state_Gurgaon  state_Hyderabad  state_Kolkata  state_Mumbai  \
# 0             False            False          False          True
# 1             False            False           True         False
# 2             False            False          False         False
# 3             False            False          False         False
# 4             False            False           True         False
# ...             ...              ...            ...           ...
# 2100          False            False           True         False
# 2101          False             True          False         False
# 2102          False            False          False         False
# 2103          False            False          False          True
# 2104          False            False          False         False
#
#       state_Noida  state_Pallikarnai  state_Poonamallee  state_Pune  \
# 0           False              False              False       False
# 1           False              False              False       False
# 2           False              False              False       False
# 3           False              False              False       False
# 4           False              False              False       False
# ...           ...                ...                ...         ...
# 2100        False              False              False       False
# 2101        False              False              False       False
# 2102        False              False              False       False
# 2103        False              False              False       False
# 2104        False              False              False        True
#
#       state_Thane  state_Thiruvallur
# 0           False              False
# 1           False              False
# 2           False              False
# 3            True              False
# 4           False              False
# ...           ...                ...
# 2100        False              False
# 2101        False              False
# 2102        False              False
# 2103        False              False
# 2104        False              False
#
# [2105 rows x 1782 columns]

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=34)

# %%
lin_model = LinearRegression()

lin_model.fit(X_train, y_train)

lin_y_preds = lin_model.predict(X_test)

# %%
lgb_model = lgb.LGBMRegressor(
    boosting_type='gbdt',
    num_leaves=31,
    n_estimators=100,
    reg_lambda=1.0
)

lgb_model.fit(X_train, y_train)

lgb_y_preds = lgb_model.predict(X_test)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000704 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 39
# [LightGBM] [Info] Number of data points in the train set: 1473, number of used features: 13
# [LightGBM] [Info] Start training from score 2017.021045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
lin_loss = np.sqrt(mean_squared_error(y_test, lin_y_preds))
lgb_loss = np.sqrt(mean_squared_error(y_test, lgb_y_preds))

# %%
print(data.columns)
# Out:
# Index(['year_of_manufacture', 'cname_Audi A3 35 TDI Premium + Sunroof',
#        'cname_Audi A3 35 TDI Premium Plus',
#        'cname_Audi A3 35 TDI Premium Plus + Sunroof',
#        'cname_Audi A3 35 TDI Technology + Sunroof',
#        'cname_Audi A3 35 TFSI Premium Plus', 'cname_Audi A3 40 TFSI Premium',
#        'cname_Audi A3 40 TFSI Premium Plus + sunroof',
#        'cname_Audi A4 2.0 TDI (143 bhp)', 'cname_Audi A4 2.0 TDI (143bhp)',
#        ...
#        'state_Gurgaon', 'state_Hyderabad', 'state_Kolkata', 'state_Mumbai',
#        'state_Noida', 'state_Pallikarnai', 'state_Poonamallee', 'state_Pune',
#        'state_Thane', 'state_Thiruvallur'],
#       dtype='object', length=1782)

# %%
#These two lines of code calculate and print the Root Mean Squared Error (RMSE) for two different models:
a Linear Regression model (lin_loss) and a Gradient Boosted model (lgb_loss).

#RMSE is a measure of the average magnitude of the errors between predicted and actual values.
Lower RMSE values indicate better model performance in terms of prediction accuracy.
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: invalid syntax (<ipython-input-23-2d7f90264a5a>, line 2)

# %%
print("Linear Regression RMSE:", lin_loss)
print("Gradient Boosted RMSE:", lgb_loss)
# Out:
# Linear Regression RMSE: 425174071316935.4
# Gradient Boosted RMSE: 2.86068559927202

# %%
print("Linear Regression R^2 Score:", lin_model.score(X_test, y_test))
print("Gradient Boosted R^2 Score:", lgb_model.score(X_test, y_test))
# Out:
# Linear Regression R^2 Score: -2.1376670786365643e+28
# Gradient Boosted R^2 Score: 0.03228653313268315

# %%
EVALUATION OF THE MODEL
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: invalid syntax (<ipython-input-26-45d7101be0bb>, line 1)

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

# Assuming you have a DataFrame 'data' with columns 'kms_driven' and 'price'
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data[['year_of_manufacture']], data['cname_Audi A3 35 TDI Premium + Sunroof'], test_size=0.2, random_state=42)

# Train a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Visualize the results using a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.scatter(X_test, y_pred, color='red', label='Predicted')
plt.xlabel('year_of_manufacture')
plt.ylabel('cname_Audi A3 35 TDI Premium + Sunroof')
plt.title('Actual vs Predicted Price')
plt.legend()
plt.show()
